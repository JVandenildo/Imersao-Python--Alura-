# %% [markdown]
# A biblioteca pandas é importante para leitura do arquivo.

# %%
import pandas as pd
import plotly.express as px

# %%
df_principal = pd.read_excel("acoes_pura.xlsx", sheet_name="Principal")
df_principal
# Out:
# c:\Python312\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Conditional Formatting extension is not supported and will be removed
#   warn(msg)
#     Ativo       Data  Último (R$)  Var. Dia (%)  Var. Sem. (%)  Var. Mês (%)  \
# 0   USIM5 2024-01-26         9.50          5.20          11.76          2.26
# 1   CMIN3 2024-01-26         6.82          2.40           2.40        -12.11
# 2   PETR3 2024-01-26        41.96          2.19           7.73          7.64
# 3   SUZB3 2024-01-26        52.91          2.04           2.14         -4.89
# 4   CPFE3 2024-01-26        37.10          2.03           2.49         -3.66
# ..    ...        ...          ...           ...            ...           ...
# 76  CRFB3 2024-01-26        10.71         -2.45          -9.47        -13.98
# 77  BHIA3 2024-01-26         8.70         -2.46          -6.95        -23.55
# 78  RENT3 2024-01-26        56.24         -3.63          -6.41        -11.57
# 79  CVCB3 2024-01-26         3.07         -4.36          -5.54        -12.29
# 80  GOLL4 2024-01-26         5.92         -8.07         -15.91        -34.00
#
#     Var. Ano (%)  Var. 12M (%)  Val. Mín  Val. Máx    Volume  Variação (%)  \
# 0           2.26         15.97      9.18      9.56  319,16 M        0.0520
# 1         -12.11         50.56      6.66      6.86   32,65 M        0.0240
# 2           7.64         77.55     40.81     42.34  436,69 M        0.0219
# 3          -4.89         18.85     51.89     53.17  162,55 M        0.0204
# 4          -3.66         20.70     36.37     37.32   73,42 M        0.0203
# ..           ...           ...       ...       ...       ...           ...
# 76        -13.98        -32.72     10.70     11.08   38,19 M       -0.0245
# 77        -23.55        -85.74      8.67      8.95   27,54 M       -0.0246
# 78        -11.57         -2.77     56.04     58.90  624,74 M       -0.0363
# 79        -12.29        -36.83      3.05      3.23  101,46 M       -0.0436
# 80        -34.00        -25.44      5.51      6.02  154,36 M       -0.0807
#
#     Valor Inicial (R$)  Qntd de ações  Variação (R$) Resultado  \
# 0             9.030418      515117391   2.418897e+08     SUBIU
# 1             6.660156     1110559345   1.775160e+08     SUBIU
# 2            41.060769     2379877655   2.140059e+09     SUBIU
# 3            51.852215      683452836   7.229463e+08     SUBIU
# 4            36.361854      187732538   1.385740e+08     SUBIU
# ..                 ...            ...            ...       ...
# 76           10.978985      533990587  -1.436355e+08    DESCEU
# 77            8.919418       94843047  -2.081024e+07    DESCEU
# 78           58.358410      853202347  -1.807433e+09    DESCEU
# 79            3.209954      525582771  -7.355741e+07    DESCEU
# 80            6.439682      198184909  -1.029932e+08    DESCEU
#
#      Nome da empresa           Segmento  Idade      Cat. Idade
# 0           Usiminas         Siderurgia     62  ENTRE 50 E 100
# 1      CSN Mineração          Mineração     20     MENOS DE 50
# 2          Petrobras           Petróleo     69  ENTRE 50 E 100
# 3             Suzano   Papel e Celulose     97  ENTRE 50 E 100
# 4       CPFL Energia            Energia    108     MAIS DE 100
# ..               ...                ...    ...             ...
# 76  Carrefour Brasil             Varejo     46     MENOS DE 50
# 77       Casas Bahia             Varejo     69  ENTRE 50 E 100
# 78          Localiza  Aluguel de carros     48     MENOS DE 50
# 79               CVC            Viagens     49     MENOS DE 50
# 80               GOL   Transporte Aéreo     20     MENOS DE 50
#
# [81 rows x 20 columns]

# %% [markdown]
# Vale prestar atenção no segundo parâmetro. Este segundo parâmetro pega a aba específica do arquivo.

# %%
df_acoesTotal = pd.read_excel("acoes_pura.xlsx", sheet_name="Total_de_acoes")
df_acoesTotal
# Out:
#                       Código  Qtde. Teórica
# 0                      RRRP3   2.356656e+08
# 1                      ALOS3   5.326166e+08
# 2                      ALPA4   1.767340e+08
# 3                      ABEV3   4.394246e+09
# 4                      ARZZ3   6.230589e+07
# ..                       ...            ...
# 84                     VBBR3   1.114413e+09
# 85                     WEGE3   1.481593e+09
# 86                     YDUQ3   2.893479e+08
# 87  Quantidade Teórica Total   9.637210e+10
# 88                   Redutor   1.704785e+07
#
# [89 rows x 2 columns]

# %%
df_ticker = pd.read_excel("acoes_pura.xlsx", sheet_name="Ticker")
df_ticker
# Out:
#     Ticker            Nome
# 0    MGLU3  Magazine Luiza
# 1    HAPV3         Hapvida
# 2    PETR4       Petrobras
# 3    B3SA3              B3
# 4    USIM5        Usiminas
# ..     ...             ...
# 530  TKNO3           Tekno
# 531  COCE6          Coelce
# 532  MGEL3         Mangels
# 533  CTSA8      Santanense
# 534  MMAQ4   Minasmáquinas
#
# [535 rows x 2 columns]

# %%
df_abaGPT = pd.read_excel("acoes_pura.xlsx", sheet_name="ChatGPT")
df_abaGPT
# Out:
#           Empresa          Segmento  Idade (anos)
# 0    3R Petroleum          Petróleo             9
# 1           ALOS3             Saúde            18
# 2      Alpargatas              Moda           113
# 3           Ambev         Alimentos            32
# 4          Arezzo              Moda            49
# ..            ...               ...           ...
# 79  Vibra Energia    Petróleo e Gás            68
# 80           Viva             Saúde            10
# 81           Vivo  Telecomunicações            27
# 82            WEG        Engenharia            60
# 83          YDUQS          Educação            55
#
# [84 rows x 3 columns]

# %%
df_principal = df_principal[['Ativo', 'Data', 'Último (R$)', 'Var. Dia (%)']].copy()
df_principal
# Out:
#     Ativo       Data  Último (R$)  Var. Dia (%)
# 0   USIM5 2024-01-26         9.50          5.20
# 1   CMIN3 2024-01-26         6.82          2.40
# 2   PETR3 2024-01-26        41.96          2.19
# 3   SUZB3 2024-01-26        52.91          2.04
# 4   CPFE3 2024-01-26        37.10          2.03
# ..    ...        ...          ...           ...
# 76  CRFB3 2024-01-26        10.71         -2.45
# 77  BHIA3 2024-01-26         8.70         -2.46
# 78  RENT3 2024-01-26        56.24         -3.63
# 79  CVCB3 2024-01-26         3.07         -4.36
# 80  GOLL4 2024-01-26         5.92         -8.07
#
# [81 rows x 4 columns]

# %%
df_principal = df_principal.rename(columns={'Último (R$)':'Valor_Final','Var. Dia (%)':'Var_Dia_pct'}).copy() # renomear as colunas para retirar os caracteres especiais
df_principal
# Out:
#     Ativo       Data  Valor_Final  Var_Dia_pct
# 0   USIM5 2024-01-26         9.50         5.20
# 1   CMIN3 2024-01-26         6.82         2.40
# 2   PETR3 2024-01-26        41.96         2.19
# 3   SUZB3 2024-01-26        52.91         2.04
# 4   CPFE3 2024-01-26        37.10         2.03
# ..    ...        ...          ...          ...
# 76  CRFB3 2024-01-26        10.71        -2.45
# 77  BHIA3 2024-01-26         8.70        -2.46
# 78  RENT3 2024-01-26        56.24        -3.63
# 79  CVCB3 2024-01-26         3.07        -4.36
# 80  GOLL4 2024-01-26         5.92        -8.07
#
# [81 rows x 4 columns]

# %%
df_principal['Var_pct'] = df_principal['Var_Dia_pct'] / 100
df_principal['Var_Inicial'] = df_principal['Valor_Final'] / (1 + df_principal['Var_pct'])
df_principal
# Out:
#     Ativo       Data  Valor_Final  Var_Dia_pct  Var_pct  Var_Inicial
# 0   USIM5 2024-01-26         9.50         5.20   0.0520     9.030418
# 1   CMIN3 2024-01-26         6.82         2.40   0.0240     6.660156
# 2   PETR3 2024-01-26        41.96         2.19   0.0219    41.060769
# 3   SUZB3 2024-01-26        52.91         2.04   0.0204    51.852215
# 4   CPFE3 2024-01-26        37.10         2.03   0.0203    36.361854
# ..    ...        ...          ...          ...      ...          ...
# 76  CRFB3 2024-01-26        10.71        -2.45  -0.0245    10.978985
# 77  BHIA3 2024-01-26         8.70        -2.46  -0.0246     8.919418
# 78  RENT3 2024-01-26        56.24        -3.63  -0.0363    58.358410
# 79  CVCB3 2024-01-26         3.07        -4.36  -0.0436     3.209954
# 80  GOLL4 2024-01-26         5.92        -8.07  -0.0807     6.439682
#
# [81 rows x 6 columns]

# %% [markdown]
# Agora, o problema requer que seja usado uma função semelhante ao `procv` do excel.

# %%
df_principal = df_principal.merge(df_acoesTotal, left_on='Ativo', right_on='Código', how='left')
df_principal
# Out:
#     Ativo       Data  Valor_Final  Var_Dia_pct  Var_pct  Var_Inicial Código  \
# 0   USIM5 2024-01-26         9.50         5.20   0.0520     9.030418  USIM5
# 1   CMIN3 2024-01-26         6.82         2.40   0.0240     6.660156  CMIN3
# 2   PETR3 2024-01-26        41.96         2.19   0.0219    41.060769  PETR3
# 3   SUZB3 2024-01-26        52.91         2.04   0.0204    51.852215  SUZB3
# 4   CPFE3 2024-01-26        37.10         2.03   0.0203    36.361854  CPFE3
# ..    ...        ...          ...          ...      ...          ...    ...
# 76  CRFB3 2024-01-26        10.71        -2.45  -0.0245    10.978985  CRFB3
# 77  BHIA3 2024-01-26         8.70        -2.46  -0.0246     8.919418  BHIA3
# 78  RENT3 2024-01-26        56.24        -3.63  -0.0363    58.358410  RENT3
# 79  CVCB3 2024-01-26         3.07        -4.36  -0.0436     3.209954  CVCB3
# 80  GOLL4 2024-01-26         5.92        -8.07  -0.0807     6.439682  GOLL4
#
#     Qtde. Teórica
# 0    5.151174e+08
# 1    1.110559e+09
# 2    2.379878e+09
# 3    6.834528e+08
# 4    1.877325e+08
# ..            ...
# 76   5.339906e+08
# 77   9.484305e+07
# 78   8.532023e+08
# 79   5.255828e+08
# 80   1.981849e+08
#
# [81 rows x 8 columns]

# %%
df_principal = df_principal.drop(columns=['Código'])
df_principal
# Out:
#     Ativo       Data  Valor_Final  Var_Dia_pct  Var_pct  Var_Inicial  \
# 0   USIM5 2024-01-26         9.50         5.20   0.0520     9.030418
# 1   CMIN3 2024-01-26         6.82         2.40   0.0240     6.660156
# 2   PETR3 2024-01-26        41.96         2.19   0.0219    41.060769
# 3   SUZB3 2024-01-26        52.91         2.04   0.0204    51.852215
# 4   CPFE3 2024-01-26        37.10         2.03   0.0203    36.361854
# ..    ...        ...          ...          ...      ...          ...
# 76  CRFB3 2024-01-26        10.71        -2.45  -0.0245    10.978985
# 77  BHIA3 2024-01-26         8.70        -2.46  -0.0246     8.919418
# 78  RENT3 2024-01-26        56.24        -3.63  -0.0363    58.358410
# 79  CVCB3 2024-01-26         3.07        -4.36  -0.0436     3.209954
# 80  GOLL4 2024-01-26         5.92        -8.07  -0.0807     6.439682
#
#     Qtde. Teórica
# 0    5.151174e+08
# 1    1.110559e+09
# 2    2.379878e+09
# 3    6.834528e+08
# 4    1.877325e+08
# ..            ...
# 76   5.339906e+08
# 77   9.484305e+07
# 78   8.532023e+08
# 79   5.255828e+08
# 80   1.981849e+08
#
# [81 rows x 7 columns]

# %%
df_principal['Variacao_RS'] = (df_principal['Valor_Final'] - df_principal['Var_Inicial'])*df_principal['Qtde. Teórica']
df_principal
# Out:
#     Ativo       Data  Valor_Final  Var_Dia_pct  Var_pct  Var_Inicial  \
# 0   USIM5 2024-01-26         9.50         5.20   0.0520     9.030418
# 1   CMIN3 2024-01-26         6.82         2.40   0.0240     6.660156
# 2   PETR3 2024-01-26        41.96         2.19   0.0219    41.060769
# 3   SUZB3 2024-01-26        52.91         2.04   0.0204    51.852215
# 4   CPFE3 2024-01-26        37.10         2.03   0.0203    36.361854
# ..    ...        ...          ...          ...      ...          ...
# 76  CRFB3 2024-01-26        10.71        -2.45  -0.0245    10.978985
# 77  BHIA3 2024-01-26         8.70        -2.46  -0.0246     8.919418
# 78  RENT3 2024-01-26        56.24        -3.63  -0.0363    58.358410
# 79  CVCB3 2024-01-26         3.07        -4.36  -0.0436     3.209954
# 80  GOLL4 2024-01-26         5.92        -8.07  -0.0807     6.439682
#
#     Qtde. Teórica   Variacao_RS
# 0    5.151174e+08  2.418897e+08
# 1    1.110559e+09  1.775160e+08
# 2    2.379878e+09  2.140059e+09
# 3    6.834528e+08  7.229463e+08
# 4    1.877325e+08  1.385740e+08
# ..            ...           ...
# 76   5.339906e+08 -1.436355e+08
# 77   9.484305e+07 -2.081024e+07
# 78   8.532023e+08 -1.807433e+09
# 79   5.255828e+08 -7.355741e+07
# 80   1.981849e+08 -1.029932e+08
#
# [81 rows x 8 columns]

# %%
pd.options.display.float_format = '{:.2f}'.format # comando para ajustar como os números são mostrados
df_principal['Qtde. Teórica'] = df_principal['Qtde. Teórica'].astype(int)
df_principal
# Out:
#     Ativo       Data  Valor_Final  Var_Dia_pct  Var_pct  Var_Inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05         9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02         6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02        41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02        51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02        36.36
# ..    ...        ...          ...          ...      ...          ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02        10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02         8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04        58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04         3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08         6.44
#
#     Qtde. Teórica    Variacao_RS
# 0       515117391   241889725.43
# 1      1110559345   177515970.30
# 2     -2147483648  2140059393.53
# 3       683452836   722946282.71
# 4       187732538   138573955.06
# ..            ...            ...
# 76      533990587  -143635530.57
# 77       94843047   -20810240.84
# 78      853202347 -1807432634.46
# 79      525582771   -73557408.06
# 80      198184909  -102993202.62
#
# [81 rows x 8 columns]

# %%
df_principal = df_principal.rename(columns={'Qtde. Teórica':'Qtde_Teorica'}).copy() # renomear a coluna para retirar os caracteres especiais
df_principal
# Out:
#     Ativo       Data  Valor_Final  Var_Dia_pct  Var_pct  Var_Inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05         9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02         6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02        41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02        51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02        36.36
# ..    ...        ...          ...          ...      ...          ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02        10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02         8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04        58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04         3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08         6.44
#
#     Qtde_Teorica    Variacao_RS
# 0      515117391   241889725.43
# 1     1110559345   177515970.30
# 2    -2147483648  2140059393.53
# 3      683452836   722946282.71
# 4      187732538   138573955.06
# ..           ...            ...
# 76     533990587  -143635530.57
# 77      94843047   -20810240.84
# 78     853202347 -1807432634.46
# 79     525582771   -73557408.06
# 80     198184909  -102993202.62
#
# [81 rows x 8 columns]

# %%
df_principal['Resultado'] = df_principal['Variacao_RS'].apply(lambda x: 'Subiu' if x > 0 else('Desceu' if x < 0 else 'Estável'))
df_principal
# Out:
#     Ativo       Data  Valor_Final  Var_Dia_pct  Var_pct  Var_Inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05         9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02         6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02        41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02        51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02        36.36
# ..    ...        ...          ...          ...      ...          ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02        10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02         8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04        58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04         3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08         6.44
#
#     Qtde_Teorica    Variacao_RS Resultado
# 0      515117391   241889725.43     Subiu
# 1     1110559345   177515970.30     Subiu
# 2    -2147483648  2140059393.53     Subiu
# 3      683452836   722946282.71     Subiu
# 4      187732538   138573955.06     Subiu
# ..           ...            ...       ...
# 76     533990587  -143635530.57    Desceu
# 77      94843047   -20810240.84    Desceu
# 78     853202347 -1807432634.46    Desceu
# 79     525582771   -73557408.06    Desceu
# 80     198184909  -102993202.62    Desceu
#
# [81 rows x 9 columns]

# %%
df_principal = df_principal.merge(df_ticker, left_on='Ativo', right_on='Ticker', how='left')
df_principal = df_principal.drop(columns='Ticker')
df_principal
# Out:
#     Ativo       Data  Valor_Final  Var_Dia_pct  Var_pct  Var_Inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05         9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02         6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02        41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02        51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02        36.36
# ..    ...        ...          ...          ...      ...          ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02        10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02         8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04        58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04         3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08         6.44
#
#     Qtde_Teorica    Variacao_RS Resultado              Nome
# 0      515117391   241889725.43     Subiu          Usiminas
# 1     1110559345   177515970.30     Subiu     CSN Mineração
# 2    -2147483648  2140059393.53     Subiu         Petrobras
# 3      683452836   722946282.71     Subiu            Suzano
# 4      187732538   138573955.06     Subiu      CPFL Energia
# ..           ...            ...       ...               ...
# 76     533990587  -143635530.57    Desceu  Carrefour Brasil
# 77      94843047   -20810240.84    Desceu       Casas Bahia
# 78     853202347 -1807432634.46    Desceu          Localiza
# 79     525582771   -73557408.06    Desceu               CVC
# 80     198184909  -102993202.62    Desceu               GOL
#
# [81 rows x 10 columns]

# %%
df_principal = df_principal.merge(df_abaGPT, left_on='Nome', right_on='Empresa', how='left')
df_principal = df_principal.drop(columns='Empresa')
df_principal
# Out:
#     Ativo       Data  Valor_Final  Var_Dia_pct  Var_pct  Var_Inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05         9.03
# 1   USIM5 2024-01-26         9.50         5.20     0.05         9.03
# 2   CMIN3 2024-01-26         6.82         2.40     0.02         6.66
# 3   PETR3 2024-01-26        41.96         2.19     0.02        41.06
# 4   SUZB3 2024-01-26        52.91         2.04     0.02        51.85
# ..    ...        ...          ...          ...      ...          ...
# 79  CRFB3 2024-01-26        10.71        -2.45    -0.02        10.98
# 80  BHIA3 2024-01-26         8.70        -2.46    -0.02         8.92
# 81  RENT3 2024-01-26        56.24        -3.63    -0.04        58.36
# 82  CVCB3 2024-01-26         3.07        -4.36    -0.04         3.21
# 83  GOLL4 2024-01-26         5.92        -8.07    -0.08         6.44
#
#     Qtde_Teorica    Variacao_RS Resultado              Nome  \
# 0      515117391   241889725.43     Subiu          Usiminas
# 1      515117391   241889725.43     Subiu          Usiminas
# 2     1110559345   177515970.30     Subiu     CSN Mineração
# 3    -2147483648  2140059393.53     Subiu         Petrobras
# 4      683452836   722946282.71     Subiu            Suzano
# ..           ...            ...       ...               ...
# 79     533990587  -143635530.57    Desceu  Carrefour Brasil
# 80      94843047   -20810240.84    Desceu       Casas Bahia
# 81     853202347 -1807432634.46    Desceu          Localiza
# 82     525582771   -73557408.06    Desceu               CVC
# 83     198184909  -102993202.62    Desceu               GOL
#
#              Segmento  Idade (anos)
# 0          Siderurgia            62
# 1          Siderurgia            72
# 2           Mineração            20
# 3            Petróleo            69
# 4    Papel e Celulose            97
# ..                ...           ...
# 79             Varejo            46
# 80             Varejo            69
# 81  Aluguel de carros            48
# 82            Viagens            49
# 83   Transporte Aéreo            20
#
# [84 rows x 12 columns]

# %%
df_principal['Cat_Idade'] = df_principal['Idade (anos)'].apply(lambda x: 'Mais de 100 anos' if x > 100 else('Menos de 50 anos' if x < 50 else 'Entre 50 e 100 anos'))
df_principal
# Out:
#     Ativo       Data  Valor_Final  Var_Dia_pct  Var_pct  Var_Inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05         9.03
# 1   USIM5 2024-01-26         9.50         5.20     0.05         9.03
# 2   CMIN3 2024-01-26         6.82         2.40     0.02         6.66
# 3   PETR3 2024-01-26        41.96         2.19     0.02        41.06
# 4   SUZB3 2024-01-26        52.91         2.04     0.02        51.85
# ..    ...        ...          ...          ...      ...          ...
# 79  CRFB3 2024-01-26        10.71        -2.45    -0.02        10.98
# 80  BHIA3 2024-01-26         8.70        -2.46    -0.02         8.92
# 81  RENT3 2024-01-26        56.24        -3.63    -0.04        58.36
# 82  CVCB3 2024-01-26         3.07        -4.36    -0.04         3.21
# 83  GOLL4 2024-01-26         5.92        -8.07    -0.08         6.44
#
#     Qtde_Teorica    Variacao_RS Resultado              Nome  \
# 0      515117391   241889725.43     Subiu          Usiminas
# 1      515117391   241889725.43     Subiu          Usiminas
# 2     1110559345   177515970.30     Subiu     CSN Mineração
# 3    -2147483648  2140059393.53     Subiu         Petrobras
# 4      683452836   722946282.71     Subiu            Suzano
# ..           ...            ...       ...               ...
# 79     533990587  -143635530.57    Desceu  Carrefour Brasil
# 80      94843047   -20810240.84    Desceu       Casas Bahia
# 81     853202347 -1807432634.46    Desceu          Localiza
# 82     525582771   -73557408.06    Desceu               CVC
# 83     198184909  -102993202.62    Desceu               GOL
#
#              Segmento  Idade (anos)            Cat_Idade
# 0          Siderurgia            62  Entre 50 e 100 anos
# 1          Siderurgia            72  Entre 50 e 100 anos
# 2           Mineração            20     Menos de 50 anos
# 3            Petróleo            69  Entre 50 e 100 anos
# 4    Papel e Celulose            97  Entre 50 e 100 anos
# ..                ...           ...                  ...
# 79             Varejo            46     Menos de 50 anos
# 80             Varejo            69  Entre 50 e 100 anos
# 81  Aluguel de carros            48     Menos de 50 anos
# 82            Viagens            49     Menos de 50 anos
# 83   Transporte Aéreo            20     Menos de 50 anos
#
# [84 rows x 13 columns]

# %%
maior = df_principal['Variacao_RS'].max()
menor = df_principal['Variacao_RS'].min()
media = df_principal['Variacao_RS'].mean()
media_subiu = df_principal[df_principal['Resultado'] == 'Subiu']['Variacao_RS'].mean()
media_desceu = df_principal[df_principal['Resultado'] == 'Desceu']['Variacao_RS'].mean()

print(f'Maior R${maior:,.2f};\nMenor R${menor:,.2f};\nMédia R${media:,.2f};\nMédia subiu R${media_subiu:,.2f};\nMédia desceu R${media_desceu:,.2f}')
# Out:
# Maior R$4,762,926,995.25
# ;Menor R$-1,807,432,634.46;
# Média R$221,607,084.56;
# Média subiu R$530,932,235.41;
# Média desceu R$-181,109,141.75

# %%
df_principal_subiu = df_principal[df_principal['Resultado'] == 'Subiu']
df_principal_subiu
# Out:
#     Ativo       Data  Valor_Final  Var_Dia_pct  Var_pct  Var_Inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05         9.03
# 1   USIM5 2024-01-26         9.50         5.20     0.05         9.03
# 2   CMIN3 2024-01-26         6.82         2.40     0.02         6.66
# 3   PETR3 2024-01-26        41.96         2.19     0.02        41.06
# 4   SUZB3 2024-01-26        52.91         2.04     0.02        51.85
# 5   CPFE3 2024-01-26        37.10         2.03     0.02        36.36
# 6   PRIO3 2024-01-26        45.69         1.98     0.02        44.80
# 7   PETR4 2024-01-26        39.96         1.73     0.02        39.28
# 8   VALE3 2024-01-26        69.50         1.66     0.02        68.37
# 9   VALE3 2024-01-26        69.50         1.66     0.02        68.37
# 10  MULT3 2024-01-26        28.19         1.58     0.02        27.75
# 11  ITUB4 2024-01-26        32.81         1.48     0.01        32.33
# 12  RDOR3 2024-01-26        27.56         1.43     0.01        27.17
# 13  BRKM5 2024-01-26        18.55         1.42     0.01        18.29
# 14  AZUL4 2024-01-26        14.27         1.42     0.01        14.07
# 15  RRRP3 2024-01-26        28.75         1.41     0.01        28.35
# 16  EQTL3 2024-01-26        35.32         1.34     0.01        34.85
# 17  CSNA3 2024-01-26        18.16         1.33     0.01        17.92
# 18  YDUQ3 2024-01-26        19.77         1.28     0.01        19.52
# 19  UGPA3 2024-01-26        28.31         1.28     0.01        27.95
# 20  MRVE3 2024-01-26         8.08         1.25     0.01         7.98
# 21  ARZZ3 2024-01-26        57.91         1.15     0.01        57.25
# 22  BBDC4 2024-01-26        15.52         1.04     0.01        15.36
# 23  BEEF3 2024-01-26         7.19         0.98     0.01         7.12
# 24  PCAR3 2024-01-26         4.14         0.97     0.01         4.10
# 25  BRFS3 2024-01-26        14.61         0.96     0.01        14.47
# 26  VIVT3 2024-01-26        51.20         0.88     0.01        50.75
# 27  RAIL3 2024-01-26        22.64         0.84     0.01        22.45
# 28  RAIL3 2024-01-26        22.64         0.84     0.01        22.45
# 29  CIEL3 2024-01-26         4.90         0.82     0.01         4.86
# 30  DXCO3 2024-01-26         7.81         0.77     0.01         7.75
# 31  TIMS3 2024-01-26        17.52         0.74     0.01        17.39
# 32  BRAP4 2024-01-26        23.22         0.73     0.01        23.05
# 33  LWSA3 2024-01-26         5.55         0.72     0.01         5.51
# 34  RECV3 2024-01-26        23.83         0.71     0.01        23.66
# 35  ITSA4 2024-01-26        10.01         0.70     0.01         9.94
# 36  BBAS3 2024-01-26        56.97         0.68     0.01        56.59
# 37  RADL3 2024-01-26        26.16         0.61     0.01        26.00
# 38  GOAU4 2024-01-26        10.08         0.59     0.01        10.02
# 39  CSAN3 2024-01-26        18.57         0.59     0.01        18.46
# 40  JBSS3 2024-01-26        24.34         0.57     0.01        24.20
# 41  MGLU3 2024-01-26         2.08         0.48     0.00         2.07
# 42  BBDC3 2024-01-26        13.75         0.36     0.00        13.70
# 43  GGBR4 2024-01-26        21.84         0.27     0.00        21.78
# 44  RAIZ4 2024-01-26         3.74         0.26     0.00         3.73
# 45  CPLE6 2024-01-26        10.07         0.19     0.00        10.05
# 46  VAMO3 2024-01-26         8.18         0.12     0.00         8.17
#
#     Qtde_Teorica   Variacao_RS Resultado                  Nome  \
# 0      515117391  241889725.43     Subiu              Usiminas
# 1      515117391  241889725.43     Subiu              Usiminas
# 2     1110559345  177515970.30     Subiu         CSN Mineração
# 3    -2147483648 2140059393.53     Subiu             Petrobras
# 4      683452836  722946282.71     Subiu                Suzano
# 5      187732538  138573955.06     Subiu          CPFL Energia
# 6      800010734  709687498.18     Subiu              PetroRio
# 7    -2147483648 3103136291.22     Subiu             Petrobras
# 8    -2147483648 4762926995.25     Subiu                  Vale
# 9    -2147483648 4762926995.25     Subiu                  Vale
# 10     268505432  117732680.08     Subiu             Multiplan
# 11   -2147483648 2297591984.33     Subiu         Itaú Unibanco
# 12    1168230366  453917907.01     Subiu             Rede D'Or
# 13     265877867   69054317.64     Subiu               Braskem
# 14     327593725   65452205.55     Subiu                  Azul
# 15     235665566   94204643.35     Subiu          3R Petroleum
# 16    1095587251  511671895.45     Subiu    Equatorial Energia
# 17     600865451  143220991.46     Subiu  Siderúrgica Nacional
# 18     289347914   72295838.99     Subiu                 YDUQS
# 19    1086411192  388705223.96     Subiu              Ultrapar
# 20     376187582   37525872.38     Subiu                   MRV
# 21      62305891   41021792.09     Subiu                Arezzo
# 22   -2147483648  822148336.41     Subiu        Banco Bradesco
# 23     261036182   18214628.10     Subiu               Minerva
# 24     159430826    6340916.22     Subiu   Grupo Pão de Açúcar
# 25    1677525446  233045769.57     Subiu                   BRF
# 26     423091712  188965307.06     Subiu                  Vivo
# 27    1218352541  229771333.63     Subiu                  Rumo
# 28    1218352541  229771333.63     Subiu                  Rumo
# 29    1095462329   43657683.38     Subiu                 Cielo
# 30     302768240   18068446.61     Subiu                 Dexco
# 31     807896814  103972807.37     Subiu                   TIM
# 32     251003438   42238249.54     Subiu             Bradespar
# 33     393173139   15598886.65     Subiu               Locaweb
# 34     275005663   46201006.00     Subiu        PetroRecôncavo
# 35   -2147483648  373853994.88     Subiu                Itaúsa
# 36    1420949112  546752087.99     Subiu       Banco do Brasil
# 37    1275798515  202352473.74     Subiu          RaiaDrogasil
# 38     660411219   39045606.94     Subiu    Metalúrgica Gerdau
# 39    1168097881  127229653.18     Subiu                 Cosan
# 40    1134986472  156573285.43     Subiu                   JBS
# 41   -2147483648   28493619.27     Subiu        Magazine Luiza
# 42    1500728902   74019610.05     Subiu        Banco Bradesco
# 43    1118525506   65779607.10     Subiu                Gerdau
# 44    1193047233   11571106.42     Subiu                Raízen
# 45    1679335290   32069789.50     Subiu                 Copel
# 46     421383330    4131341.16     Subiu           Grupo Vamos
#
#             Segmento  Idade (anos)            Cat_Idade
# 0         Siderurgia            62  Entre 50 e 100 anos
# 1         Siderurgia            72  Entre 50 e 100 anos
# 2          Mineração            20     Menos de 50 anos
# 3           Petróleo            69  Entre 50 e 100 anos
# 4   Papel e Celulose            97  Entre 50 e 100 anos
# 5            Energia           108     Mais de 100 anos
# 6           Petróleo             8     Menos de 50 anos
# 7           Petróleo            69  Entre 50 e 100 anos
# 8          Mineração            80  Entre 50 e 100 anos
# 9          Mineração            75  Entre 50 e 100 anos
# 10       Imobiliário            52  Entre 50 e 100 anos
# 11        Financeiro            13     Menos de 50 anos
# 12             Saúde            50  Entre 50 e 100 anos
# 13           Química            21     Menos de 50 anos
# 14  Transporte Aéreo            14     Menos de 50 anos
# 15          Petróleo             9     Menos de 50 anos
# 16           Energia            23     Menos de 50 anos
# 17        Siderurgia            80  Entre 50 e 100 anos
# 18          Educação            55  Entre 50 e 100 anos
# 19    Petróleo e Gás            88  Entre 50 e 100 anos
# 20        Construção            41     Menos de 50 anos
# 21              Moda            49     Menos de 50 anos
# 22        Financeiro            78  Entre 50 e 100 anos
# 23         Alimentos            30     Menos de 50 anos
# 24            Varejo            71  Entre 50 e 100 anos
# 25         Alimentos            86  Entre 50 e 100 anos
# 26  Telecomunicações            27     Menos de 50 anos
# 27        Transporte             9     Menos de 50 anos
# 28         Logística            28     Menos de 50 anos
# 29           FinTech            23     Menos de 50 anos
# 30        Metalurgia            19     Menos de 50 anos
# 31  Telecomunicações            27     Menos de 50 anos
# 32        Financeiro            31     Menos de 50 anos
# 33        Tecnologia            24     Menos de 50 anos
# 34          Petróleo            10     Menos de 50 anos
# 35        Financeiro            53  Entre 50 e 100 anos
# 36        Financeiro           214     Mais de 100 anos
# 37             Saúde           119     Mais de 100 anos
# 38        Siderurgia           120     Mais de 100 anos
# 39           Energia            25     Menos de 50 anos
# 40         Alimentos            68  Entre 50 e 100 anos
# 41            Varejo            64  Entre 50 e 100 anos
# 42        Financeiro            78  Entre 50 e 100 anos
# 43        Siderurgia           120     Mais de 100 anos
# 44           Energia            11     Menos de 50 anos
# 45           Energia            65  Entre 50 e 100 anos
# 46         Logística             4     Menos de 50 anos

# %%
df_analise_segmento = df_principal_subiu.groupby('Segmento')['Variacao_RS'].sum().reset_index()
df_analise_segmento
# Out:
#             Segmento   Variacao_RS
# 0          Alimentos  407833683.09
# 1         Construção   37525872.38
# 2           Educação   72295838.99
# 3            Energia  821116399.61
# 4            FinTech   43657683.38
# 5         Financeiro 4156604263.21
# 6        Imobiliário  117732680.08
# 7          Logística  233902674.79
# 8         Metalurgia   18068446.61
# 9          Mineração 9703369960.80
# 10              Moda   41021792.09
# 11  Papel e Celulose  722946282.71
# 12          Petróleo 6093288832.26
# 13    Petróleo e Gás  388705223.96
# 14           Química   69054317.64
# 15             Saúde  656270380.75
# 16        Siderurgia  731825656.36
# 17        Tecnologia   15598886.65
# 18  Telecomunicações  292938114.42
# 19        Transporte  229771333.63
# 20  Transporte Aéreo   65452205.55
# 21            Varejo   34834535.50

# %%
df_analise_saldo = df_principal.groupby('Resultado')['Variacao_RS'].sum().reset_index()
df_analise_saldo
# Out:
#   Resultado    Variacao_RS
# 0    Desceu -6338819961.32
# 1   Estável           0.00
# 2     Subiu 24953815064.46

# %% [markdown]
# Criação de gráficos.

# %%
fig = px.bar(df_analise_saldo, x='Resultado', y='Variacao_RS', text='Variacao_RS', title='Variação R$ por resultado')
fig.show()
